# %%
# Common
import numpy as np 
import pandas as pd

# Data Visualization
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
from matplotlib import colors

# %%
car_df = pd.read_csv('../input/car-details-dataset/CAR DETAILS FROM CAR DEKHO.csv')
car_df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
sns.set(rc={"axes.facecolor":"#ffe4ad","figure.facecolor":"#ffe4ad"})
pallet = ["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"]
cmap = colors.ListedColormap(["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"])

ax = car_df['name'].value_counts().head(10).sort_values().plot(kind='barh', figsize=(8,5), cmap='Paired_r')
ax.bar_label(ax.containers[0], )
# Out:
# [Text(0, 0, '24'),
#  Text(0, 0, '24'),
#  Text(0, 0, '27'),
#  Text(0, 0, '29'),
#  Text(0, 0, '29'),
#  Text(0, 0, '35'),
#  Text(0, 0, '35'),
#  Text(0, 0, '47'),
#  Text(0, 0, '59'),
#  Text(0, 0, '69')]

# %%
car_df["make"] = car_df.name.apply(lambda x : x.split(' ')[0])
car_df.loc[:,"make"] = car_df.make.apply(lambda x : "Rare Brand" if car_df.make.value_counts(normalize = True)[x] < 0.01  else x)
car_df.make.value_counts(normalize = False).plot(kind = "bar", cmap='Paired_r')
plt.show()

# %%
ax = car_df['year'].value_counts().head(10).sort_values().plot(kind='barh', figsize=(8,5), cmap='Paired_r')
plt.xlabel("Count", labelpad=14)
plt.ylabel("Year", labelpad=14)
plt.title("Total of Selling Car each Years", y=1.02);

# %%
sns.set(rc={"axes.facecolor":"#ffe4ad","figure.facecolor":"#ffe4ad"})
pallet = ["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"]
cmap = colors.ListedColormap(["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"])
plt.figure(figsize=(6,4))
sns.histplot(data=car_df,x='selling_price',kde=True,hue='transmission');

# %%
plt.figure(figsize=(6,4))
sns.histplot(data=car_df,x='km_driven',kde=True,hue='transmission');

# %%
ax = car_df['fuel'].value_counts().head(10).sort_values().plot(kind='barh', figsize=(8,3), cmap='Paired_r')
ax.bar_label(ax.containers[0], )
plt.xlabel("Count", labelpad=14)
plt.ylabel("fuel", labelpad=14)
plt.title("Total of Selling Car Depend of Fuel", y=1.02);

# %%
ax = car_df['seller_type'].value_counts().head(10).sort_values().plot(kind='barh', figsize=(8,3), cmap='Paired_r')
ax.bar_label(ax.containers[0], )
plt.xlabel("Count", labelpad=14)
plt.ylabel("Seller Type", labelpad=14)
plt.title("Total of Selling Car Depend of Seller Type", y=1.02);

# %%
ax = car_df['transmission'].value_counts().head(10).sort_values().plot(kind='barh', figsize=(8,3), cmap='Paired_r')
ax.bar_label(ax.containers[0], )
plt.xlabel("Count", labelpad=14)
plt.ylabel("transmission", labelpad=14)
plt.title("Total of Selling Car Depend of Transmission", y=1.02);

# %%
ax = car_df['owner'].value_counts().head(10).sort_values().plot(kind='barh', figsize=(8,3), cmap='Paired_r')
ax.bar_label(ax.containers[0], )
plt.xlabel("Count", labelpad=14)
plt.ylabel("Owner", labelpad=14)
plt.title("Total of Selling Car Depend of Owner", y=1.02);

# %%
labels=car_df['owner'].value_counts().index
colors=['coral','pink','orange','green','yellow']
explode=[0,0.1,0,0,0]
values=car_df['owner'].value_counts().values

#visualization
plt.figure(figsize=(4,4))
plt.pie(values,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%')
plt.title('Owner Presentage',color='brown',fontsize=15)
plt.show()

# %%
labels=car_df['transmission'].value_counts().index
colors=['coral','pink']
explode=[0,0.1]
values=car_df['transmission'].value_counts().values

#visualization
plt.figure(figsize=(4,4))
plt.pie(values,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%')
plt.title('Transmission Presentage',color='brown',fontsize=13)
plt.show()

# %%
labels=car_df['fuel'].value_counts().index
colors=['coral','pink','orange','green','yellow']
explode=[0,0,0.1,0,0]
values=car_df['fuel'].value_counts().values

#visualization
plt.figure(figsize=(5,5))
plt.pie(values,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%')
plt.title('Fuel Presentage',color='brown',fontsize=15)
plt.show()

# %%
labels=car_df['fuel'].value_counts().index
colors=['coral','pink','orange','green','yellow']
explode=[0,0,0.1,0,0]
values=car_df['fuel'].value_counts().values

#visualization
plt.figure(figsize=(7,7))
plt.pie(values,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%')
plt.title('Fuel Presentage',color='brown',fontsize=15)
plt.show()

# %%
labels=car_df['seller_type'].value_counts().index
colors=['coral','pink', 'orange']
explode=[0,0.1,0]
values=car_df['seller_type'].value_counts().values

#visualization
plt.figure(figsize=(4,4))
plt.pie(values,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%')
plt.title('Seller Type Presentage',color='brown',fontsize=13)
plt.show()

# %%
car_df['marka'] = car_df['name'].str.split(' ').str[0]

# %%
df_marka_price = car_df.groupby(['marka'])[['selling_price']].mean()
df_marka_price.sort_values(by='selling_price', ascending=True, inplace=True)
ax   = df_marka_price.plot(kind='barh', cmap='Oranges_r' , figsize=(10,12) ,title= 'Avarege Selling Price', )
for c in ax.containers:
        # set the bar label
    ax.bar_label(c, fmt='%.0f',label_type='center', color='w',rotation=0)

# %%
top_5 = ["Maruti", "Hyundai", "Mahindra", "Tata", "Honda"]
top_5_df = car_df[car_df.make.isin(top_5)]
fig, ax = plt.subplots(figsize = (5,5))
sns.violinplot(data = top_5_df, x = "make", y = "selling_price", order = top_5, ax = ax, palette='Oranges')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
top_5 = ["Maruti", "Hyundai", "Mahindra", "Tata", "Honda"]
top_5_df = car_df[car_df.make.isin(top_5)]
fig, ax = plt.subplots(figsize = (7,3))
sns.barplot(data = top_5_df, x = "make", y = "selling_price", order = top_5, hue ="transmission", ax = ax, palette='Oranges')
plt.show

fig, ax = plt.subplots(figsize = (7,3))
car_df["Price Ratio"] = car_df.km_driven / car_df.selling_price
sns.boxplot(data = car_df[car_df.make.isin(top_5)], x = "make", y = "Price Ratio", hue ="transmission", ax = ax, palette='Oranges')
plt.show()

# %%
top_5 = ["Maruti", "Hyundai", "Mahindra", "Tata", "Honda"]
top_5_df = car_df[car_df.make.isin(top_5)]
fig, ax = plt.subplots(figsize = (7,3))
sns.barplot(data = top_5_df, x = "make", y = "selling_price", order = top_5, hue ="fuel", ax = ax, palette='Oranges')
plt.show
fig, ax = plt.subplots(figsize = (7,3))
car_df["Price Ratio"] = car_df.km_driven / car_df.selling_price
sns.boxplot(data = car_df[car_df.make.isin(top_5)], x = "make", y = "Price Ratio", hue ="fuel", ax = ax, palette='Oranges')
plt.show()

# %%
top_5 = ["Maruti", "Hyundai", "Mahindra", "Tata", "Honda"]
top_5_df = car_df[car_df.make.isin(top_5)]
fig, ax = plt.subplots(figsize = (7,3))
sns.barplot(data = top_5_df, x = "make", y = "selling_price", order = top_5, hue ="owner", ax = ax, palette='Oranges')
plt.show

fig, ax = plt.subplots(figsize = (7,3))
car_df["Price Ratio"] = car_df.km_driven / car_df.selling_price
sns.boxplot(data = car_df[car_df.make.isin(top_5)], x = "make", y = "Price Ratio", hue ="owner", ax = ax, palette='Oranges')
plt.show()

# %%
top_5 = ["Maruti", "Hyundai", "Mahindra", "Tata", "Honda"]
top_5_df = car_df[car_df.make.isin(top_5)]
fig, ax = plt.subplots(figsize = (7,3))
sns.barplot(data = top_5_df, x = "make", y = "selling_price", order = top_5, hue ="seller_type", ax = ax, palette='Oranges')
plt.show
fig, ax = plt.subplots(figsize = (7,3))
car_df["Price Ratio"] = car_df.km_driven / car_df.selling_price
sns.boxplot(data = car_df[car_df.make.isin(top_5)], x = "make", y = "Price Ratio", hue ="seller_type", ax = ax, palette='Oranges')
plt.show()

# %%
car_df.groupby("year")["owner"].value_counts().unstack().fillna(0).astype(
    "int"
).style.background_gradient(cmap="Oranges")
# Out:
# <style type="text/css">
# #T_d4cb5_row0_col0, #T_d4cb5_row0_col2, #T_d4cb5_row0_col3, #T_d4cb5_row0_col4, #T_d4cb5_row1_col0, #T_d4cb5_row1_col1, #T_d4cb5_row1_col3, #T_d4cb5_row1_col4, #T_d4cb5_row2_col0, #T_d4cb5_row2_col1, #T_d4cb5_row2_col3, #T_d4cb5_row2_col4, #T_d4cb5_row3_col0, #T_d4cb5_row3_col1, #T_d4cb5_row3_col3, #T_d4cb5_row4_col0, #T_d4cb5_row4_col3, #T_d4cb5_row5_col0, #T_d4cb5_row5_col3, #T_d4cb5_row6_col3, #T_d4cb5_row7_col3, #T_d4cb5_row8_col3, #T_d4cb5_row9_col3, #T_d4cb5_row10_col3, #T_d4cb5_row11_col3, #T_d4cb5_row12_col3, #T_d4cb5_row13_col3, #T_d4cb5_row14_col3, #T_d4cb5_row15_col3, #T_d4cb5_row16_col3, #T_d4cb5_row17_col3, #T_d4cb5_row18_col3, #T_d4cb5_row19_col3, #T_d4cb5_row20_col3, #T_d4cb5_row21_col3, #T_d4cb5_row22_col1, #T_d4cb5_row22_col3, #T_d4cb5_row24_col1, #T_d4cb5_row25_col1, #T_d4cb5_row26_col2, #T_d4cb5_row26_col4 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_d4cb5_row0_col1, #T_d4cb5_row7_col1, #T_d4cb5_row10_col2, #T_d4cb5_row21_col1, #T_d4cb5_row23_col1, #T_d4cb5_row26_col1 {
#   background-color: #fee9d4;
#   color: #000000;
# }
# #T_d4cb5_row1_col2, #T_d4cb5_row2_col2, #T_d4cb5_row3_col2 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_d4cb5_row3_col4, #T_d4cb5_row5_col4, #T_d4cb5_row10_col0, #T_d4cb5_row24_col4 {
#   background-color: #fff2e5;
#   color: #000000;
# }
# #T_d4cb5_row4_col1, #T_d4cb5_row5_col1, #T_d4cb5_row8_col1, #T_d4cb5_row9_col1 {
#   background-color: #fdc38d;
#   color: #000000;
# }
# #T_d4cb5_row4_col2, #T_d4cb5_row7_col2, #T_d4cb5_row8_col2 {
#   background-color: #fff0e2;
#   color: #000000;
# }
# #T_d4cb5_row4_col4 {
#   background-color: #feead6;
#   color: #000000;
# }
# #T_d4cb5_row5_col2, #T_d4cb5_row25_col2 {
#   background-color: #fff1e4;
#   color: #000000;
# }
# #T_d4cb5_row6_col0, #T_d4cb5_row7_col0 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_d4cb5_row6_col1, #T_d4cb5_row11_col1, #T_d4cb5_row20_col1 {
#   background-color: #fdd9b4;
#   color: #000000;
# }
# #T_d4cb5_row6_col2 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_d4cb5_row6_col4, #T_d4cb5_row9_col4, #T_d4cb5_row23_col4, #T_d4cb5_row25_col4 {
#   background-color: #ffeedd;
#   color: #000000;
# }
# #T_d4cb5_row7_col4, #T_d4cb5_row10_col4, #T_d4cb5_row11_col2 {
#   background-color: #fdd1a4;
#   color: #000000;
# }
# #T_d4cb5_row8_col0, #T_d4cb5_row9_col0 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_d4cb5_row8_col4, #T_d4cb5_row22_col4 {
#   background-color: #fee2c6;
#   color: #000000;
# }
# #T_d4cb5_row9_col2, #T_d4cb5_row11_col0 {
#   background-color: #feecda;
#   color: #000000;
# }
# #T_d4cb5_row10_col1, #T_d4cb5_row18_col1 {
#   background-color: #f3701b;
#   color: #f1f1f1;
# }
# #T_d4cb5_row11_col4, #T_d4cb5_row20_col4 {
#   background-color: #fda159;
#   color: #000000;
# }
# #T_d4cb5_row12_col0 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_d4cb5_row12_col1, #T_d4cb5_row15_col2, #T_d4cb5_row19_col1 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_d4cb5_row12_col2 {
#   background-color: #fdb678;
#   color: #000000;
# }
# #T_d4cb5_row12_col4 {
#   background-color: #dd4d04;
#   color: #f1f1f1;
# }
# #T_d4cb5_row13_col0 {
#   background-color: #feead5;
#   color: #000000;
# }
# #T_d4cb5_row13_col1, #T_d4cb5_row16_col1 {
#   background-color: #9e3303;
#   color: #f1f1f1;
# }
# #T_d4cb5_row13_col2 {
#   background-color: #fd9b50;
#   color: #000000;
# }
# #T_d4cb5_row13_col4, #T_d4cb5_row19_col4, #T_d4cb5_row21_col4 {
#   background-color: #f9802d;
#   color: #f1f1f1;
# }
# #T_d4cb5_row14_col0 {
#   background-color: #fee4ca;
#   color: #000000;
# }
# #T_d4cb5_row14_col1, #T_d4cb5_row17_col1 {
#   background-color: #fda762;
#   color: #000000;
# }
# #T_d4cb5_row14_col2 {
#   background-color: #fdb576;
#   color: #000000;
# }
# #T_d4cb5_row14_col4 {
#   background-color: #9b3203;
#   color: #f1f1f1;
# }
# #T_d4cb5_row15_col0 {
#   background-color: #fedcbb;
#   color: #000000;
# }
# #T_d4cb5_row15_col1, #T_d4cb5_row17_col4, #T_d4cb5_row18_col2, #T_d4cb5_row23_col0, #T_d4cb5_row26_col3 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_d4cb5_row15_col4, #T_d4cb5_row16_col4 {
#   background-color: #882a04;
#   color: #f1f1f1;
# }
# #T_d4cb5_row16_col0 {
#   background-color: #fdd7af;
#   color: #000000;
# }
# #T_d4cb5_row16_col2 {
#   background-color: #e4580a;
#   color: #f1f1f1;
# }
# #T_d4cb5_row17_col0 {
#   background-color: #fdc590;
#   color: #000000;
# }
# #T_d4cb5_row17_col2 {
#   background-color: #da4902;
#   color: #f1f1f1;
# }
# #T_d4cb5_row18_col0 {
#   background-color: #f98230;
#   color: #f1f1f1;
# }
# #T_d4cb5_row18_col4 {
#   background-color: #912e04;
#   color: #f1f1f1;
# }
# #T_d4cb5_row19_col0 {
#   background-color: #f36e19;
#   color: #f1f1f1;
# }
# #T_d4cb5_row19_col2 {
#   background-color: #e35608;
#   color: #f1f1f1;
# }
# #T_d4cb5_row20_col0 {
#   background-color: #fa8532;
#   color: #f1f1f1;
# }
# #T_d4cb5_row20_col2 {
#   background-color: #b53b02;
#   color: #f1f1f1;
# }
# #T_d4cb5_row21_col0 {
#   background-color: #d64701;
#   color: #f1f1f1;
# }
# #T_d4cb5_row21_col2 {
#   background-color: #fb8634;
#   color: #f1f1f1;
# }
# #T_d4cb5_row22_col0 {
#   background-color: #e05206;
#   color: #f1f1f1;
# }
# #T_d4cb5_row22_col2 {
#   background-color: #fdbe84;
#   color: #000000;
# }
# #T_d4cb5_row23_col2 {
#   background-color: #fdd4aa;
#   color: #000000;
# }
# #T_d4cb5_row23_col3, #T_d4cb5_row24_col3 {
#   background-color: #feebd8;
#   color: #000000;
# }
# #T_d4cb5_row24_col0 {
#   background-color: #c34002;
#   color: #f1f1f1;
# }
# #T_d4cb5_row24_col2 {
#   background-color: #fee5cb;
#   color: #000000;
# }
# #T_d4cb5_row25_col0 {
#   background-color: #fd9f56;
#   color: #000000;
# }
# #T_d4cb5_row25_col3 {
#   background-color: #fdd0a2;
#   color: #000000;
# }
# #T_d4cb5_row26_col0 {
#   background-color: #feecd9;
#   color: #000000;
# }
# </style>
# <table id="T_d4cb5_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >owner</th>
#       <th class="col_heading level0 col0" >First Owner</th>
#       <th class="col_heading level0 col1" >Fourth & Above Owner</th>
#       <th class="col_heading level0 col2" >Second Owner</th>
#       <th class="col_heading level0 col3" >Test Drive Car</th>
#       <th class="col_heading level0 col4" >Third Owner</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4cb5_level0_row0" class="row_heading level0 row0" >1992</th>
#       <td id="T_d4cb5_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d4cb5_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_d4cb5_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_d4cb5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d4cb5_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d4cb5_level0_row1" class="row_heading level0 row1" >1995</th>
#       <td id="T_d4cb5_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_d4cb5_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_d4cb5_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_d4cb5_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_d4cb5_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d4cb5_level0_row2" class="row_heading level0 row2" >1996</th>
#       <td id="T_d4cb5_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_d4cb5_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_d4cb5_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_d4cb5_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_d4cb5_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d4cb5_level0_row3" class="row_heading level0 row3" >1997</th>
#       <td id="T_d4cb5_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_d4cb5_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_d4cb5_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_d4cb5_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_d4cb5_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d4cb5_level0_row4" class="row_heading level0 row4" >1998</th>
#       <td id="T_d4

# %%
sns.set(rc={"axes.facecolor":"#ffe4ad","figure.facecolor":"#ffe4ad"})
pallet = ["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"]
cmap = colors.ListedColormap(["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"])
df_owner = car_df.query('year > 2010')
df_owner = (
    df_owner.groupby("year")["owner"]
    .value_counts()
    .sort_index()
    .unstack()
)
ax = df_owner.T.plot(kind="bar", figsize=(7, 3))
ax.set_title("In the Past Ten Years ", fontsize=14)
ax.set_ylabel("Total of owner salse")
plt.xticks(rotation=-45, ha="left")
plt.show()

# %%
plt.figure(figsize=(7,3))
sns.lineplot(data=car_df, x="year", y="selling_price", hue="fuel", ci=False)
plt.title("Change in Price Over Years for Depend on Fuel Type")
# Out:
# Text(0.5, 1.0, 'Change in Price Over Years for Depend on Fuel Type')

# %%
plt.figure(figsize=(7,3))
sns.lineplot(data=car_df, x="year", y="selling_price", hue="seller_type", ci=False)
plt.title("Change in Price Over Years Depend on Seller Typee")
# Out:
# Text(0.5, 1.0, 'Change in Price Over Years Depend on Seller Typee')

# %%
sns.set(rc={"axes.facecolor":"#ffe4ad","figure.facecolor":"#ffe4ad"})
pallet = ["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"]
cmap = colors.ListedColormap(["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"])
df_owner = car_df.query('year > 2010')
df_owner = (
    df_owner.groupby("year")["seller_type"]
    .value_counts()
    .sort_index()
    .unstack()
)
ax = df_owner.T.plot(kind="bar", figsize=(6, 3))
ax.set_title("In the Past Ten Years ", fontsize=14)
ax.set_ylabel("Total of seller_type")
plt.xticks(rotation=-45, ha="left")
plt.show()

# %%
plt.figure(figsize=(7,3))
sns.lineplot(data=car_df, x="year", y="selling_price", hue="transmission", ci=False)
plt.title("Change in Price Over Years depend on Transmission Type")

# %%
sns.set(rc={"axes.facecolor":"#ffe4ad","figure.facecolor":"#ffe4ad"})
pallet = ["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"]
cmap = colors.ListedColormap(["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"])
df_owner = car_df.query('year > 2010')
df_owner = (
    df_owner.groupby("year")["transmission"]
    .value_counts()
    .sort_index()
    .unstack()
)
ax = df_owner.T.plot(kind="bar", figsize=(6, 5))
ax.set_title("In the Past Ten Years ", fontsize=14)
ax.set_ylabel("Total of Transmission")
plt.xticks(rotation=-45, ha="left")
plt.show()

# %%
plt.figure(figsize=(7,3))
sns.lineplot(data=car_df, x="year", y="selling_price", hue="owner", ci=False)
plt.title("change in price over years Depend on Owner")
# Out:
# Text(0.5, 1.0, 'change in price over years Depend on Owner')

# %%
sns.set(rc={"axes.facecolor":"#ffe4ad","figure.facecolor":"#ffe4ad"})
pallet = ["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"]
cmap = colors.ListedColormap(["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"])
df_owner = car_df.query('year > 2010')
df_owner = (
    df_owner.groupby("year")["owner"]
    .value_counts()
    .sort_index()
    .unstack()
)
ax = df_owner.T.plot(kind="bar", figsize=(7, 3))
ax.set_title("In the Past Ten Years ", fontsize=14)
ax.set_ylabel("Total")
plt.xticks(rotation=-45, ha="left")
plt.show()

# %%
plt.figure(figsize=(7,3))
sns.lineplot(data=car_df, x="year", y="km_driven", hue="owner", ci=False)
plt.title("Change in km_Driven Over Years Depend on Owner Type")
# Out:
# Text(0.5, 1.0, 'Change in km_Driven Over Years Depend on Owner Type')

# %%
plt.figure(figsize=(7,3))
sns.lineplot(data=car_df, x="year", y="km_driven", hue="fuel", ci=False)
plt.title("Change in km_Driven Over Years Depend on Fuel Type")
# Out:
# Text(0.5, 1.0, 'Change in km_Driven Over Years Depend on Fuel Type')

# %%
plt.figure(figsize=(7,3))
sns.lineplot(data=car_df, x="year", y="km_driven", hue="transmission", ci=False)
plt.title("Change in km_Driven Over Years Depend on Transmission Type")
# Out:
# Text(0.5, 1.0, 'Change in km_Driven Over Years Depend on Transmission Type')
