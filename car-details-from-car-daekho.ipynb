# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/kaggle/input/car-details-dataset/CAR DETAILS FROM CAR DEKHO.csv')

# %% [markdown]
# # **READ DATA**

# %%
# top 5 data
data.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
# Check List Column Name
list_data = list(data)
print(list_data)

print('\n')

#Check Unique Data in One Column
print(data['owner'].unique())
# Out:
# ['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type', 'transmission', 'owner']
#
#
# ['First Owner' 'Second Owner' 'Fourth & Above Owner' 'Third Owner'
#  'Test Drive Car']

# %%
# Read all Data
print(data)
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
print(data.shape)
# Out:
# (4340, 8)

# %% [markdown]
# **we can see that the data, has 8 columns and 4340 rows, with a list of column names is name, year, selling_price, km_driven, fuel, seller_type, transmission, owner**

# %% [markdown]
# # **CHECK FOR NULL DATA**

# %%
#check null data
print(data.isnull())

print('\nData Information:')
print(data.info())
# Out:
#        name   year  selling_price  km_driven   fuel  seller_type  \
# 0     False  False          False      False  False        False
# 1     False  False          False      False  False        False
# 2     False  False          False      False  False        False
# 3     False  False          False      False  False        False
# 4     False  False          False      False  False        False
# ...     ...    ...            ...        ...    ...          ...
# 4335  False  False          False      False  False        False
# 4336  False  False          False      False  False        False
# 4337  False  False          False      False  False        False
# 4338  False  False          False      False  False        False
# 4339  False  False          False      False  False        False
#
#       transmission  owner
# 0            False  False
# 1            False  False
# 2            False  False
# 3            False  False
# 4            False  False
# ...

# %%
#checking missing value for each feature  
print('Checking missing value for each feature:')
print(data.isnull().sum())
#Counting total missing value
print('\nCounting total missing value:')
print(data.isnull().sum().sum())
# Out:
# Checking missing value for each feature:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64
#
# Counting total missing value:
# 0

# %% [markdown]
# **we can see that there is no null data in this case, so we can continue to next step**

# %% [markdown]
# # **DESCRIPTIVE STATISTICS**

# %%
# statistics from data: for numeric
print('\nDescriptive statistics:\n', data.describe())
# Out:
# Descriptive statistics:
#                year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
# Correlation
data_corr = data.corr()
print('Korelasi dataset:\n', data.corr())
# Out:
# Korelasi dataset:
#                     year  selling_price  km_driven
# year           1.000000       0.413922  -0.419688
# selling_price  0.413922       1.000000  -0.192289
# km_driven     -0.419688      -0.192289   1.000000

# %%
# statistics from data: for numeric and non-numeric data
print((data).describe(include="all"))
# Out:
#                           name         year  selling_price      km_driven  \
# count                     4340  4340.000000   4.340000e+03    4340.000000
# unique                    1491          NaN            NaN            NaN
# top     Maruti Swift Dzire VDI          NaN            NaN            NaN
# freq                        69          NaN            NaN            NaN
# mean                       NaN  2013.090783   5.041273e+05   66215.777419
# std                        NaN     4.215344   5.785487e+05   46644.102194
# min                        NaN  1992.000000   2.000000e+04       1.000000
# 25%                        NaN  2011.000000   2.087498e+05   35000.000000
# 50%                        NaN  2014.000000   3.500000e+05   60000.000000
# 75%                        NaN  2016.000000   6.000000e+05   90000.000000
# max                        NaN  2020.000000   8.900000e+06  806599.000000
#
#           fuel seller_type transmission        owner
# ...

# %%
#statistics of non-numeric data
print((data).describe(include="object"))
# Out:
#                           name    fuel seller_type transmission        owner
# count                     4340    4340        4340         4340         4340
# unique                    1491       5           3            2            5
# top     Maruti Swift Dzire VDI  Diesel  Individual       Manual  First Owner
# freq                        69    2153        3244         3892         2832

# %% [markdown]
# # **DATA VISUALIZATION**

# %%
# First Plot: Making a Line Chart of Selling Price Growth Trends
data.groupby(['year'])['selling_price'].sum().plot()
plt.show()

# %%
plt.figure(figsize=(15,5))
data.groupby(['year'])['selling_price'].sum().plot()
plt.title('Total Selling Price in Every Year', loc='center', pad=20, fontsize=20, color='blue')
plt.xlabel('Year')
plt.ylabel('Selling Price')
plt.show()

# %% [markdown]
# > **Total Selling Price in Every Year - Breakdown by Seller Type**

# %%
# Multi Line Chart

data.groupby(['year','seller_type'])['selling_price'].sum().unstack().plot()
plt.title('Total Selling Price in Every Year - Breakdown by Seller Type', loc='center',pad=30, fontsize=20, color='blue')
plt.xlabel('Year', fontsize = 15)
plt.ylabel('Total Selling(in Millions)', fontsize = 15)
plt.grid(color='darkgray', linestyle=':', linewidth=0.5)
plt.ylim(ymin=0)
labels, locations = plt.yticks()
plt.yticks(labels, (labels/1000000).astype(int))
plt.gcf().set_size_inches(10, 5)
plt.tight_layout()
plt.show()

# %%
# Bar Chart
plt.clf()
plt.figure(figsize=(7,7))
data_sum = data.groupby('seller_type')['selling_price'].sum().reset_index()
data_sum.groupby('seller_type')['selling_price'].sum().sort_values(ascending=False).plot(kind='bar', color='green')
plt.title('Total Selling Price in All Year - Breakdown by Seller Type', loc='center', pad=30, fontsize=15, color='blue')
plt.xlabel('Seller Type', fontsize=15)
plt.ylabel('Total Selling Price (in Millions)', fontsize=15)
plt.ylim(ymin=0)
labels, locations = plt.yticks()
plt.yticks(labels, (labels/1000000).astype(int))
plt.xticks(rotation=0)
plt.show()

# %%
# Pie Chart
data_sum = data.groupby('seller_type')['selling_price'].sum().reset_index()

plt.figure(figsize=(7,7))
plt.pie(data_sum['selling_price'], labels = data_sum['seller_type'], autopct='%1.2f%%')
plt.title('Total Selling Price in All Year - Breakdown by Seller Type', loc='center', pad=30, fontsize=15, color='blue')
plt.show()

# %% [markdown]
# **We can see that the individual seller_type dominates car sales in this case with 62,94 %, followed by Dealers and Trustmark Dealers. so we can say individual dealer sales account for the majority of car sales in this case, with the highest sales in 2017**

# %% [markdown]
# > **Total Selling Price in Every Year - Breakdown by Owner**

# %%
# Multi Line Chart

data.groupby(['year','owner'])['selling_price'].sum().unstack().plot()
plt.title('Total Selling Price in Every Year - Breakdown by Owner', loc='center',pad=30, fontsize=20, color='blue')
plt.xlabel('Year', fontsize = 15)
plt.ylabel('Total Selling(in Millions)', fontsize = 15)
plt.grid(color='darkgray', linestyle=':', linewidth=0.5)
plt.ylim(ymin=0)
labels, locations = plt.yticks()
plt.yticks(labels, (labels/1000000).astype(int))
plt.gcf().set_size_inches(10, 5)
plt.tight_layout()
plt.show()

# %%
# Bar Chart
plt.clf()
plt.figure(figsize=(7,7))
data_sum = data.groupby('owner')['selling_price'].sum().reset_index()
data_sum.groupby('owner')['selling_price'].sum().sort_values(ascending=False).plot(kind='bar', color='green')
plt.title('Total Selling Price in All Year - Breakdown by Owner', loc='center', pad=30, fontsize=15, color='blue')
plt.xlabel('Owner', fontsize=15)
plt.ylabel('Total Selling Price (in Millions)', fontsize=15)
plt.ylim(ymin=0)
labels, locations = plt.yticks()
plt.yticks(labels, (labels/1000000).astype(int))
plt.xticks(rotation=0)
plt.show()

# %%
# Pie Chart
data_sum = data.groupby('owner')['selling_price'].sum().reset_index()

plt.figure(figsize=(7,7))
plt.pie(data_sum['selling_price'], labels = data_sum['owner'], autopct='%1.2f%%')
plt.title('Total Selling Price in All Year - Breakdown by Owner', loc='center', pad=30, fontsize=15, color='blue')
plt.show()

# %% [markdown]
# **From the graph, we can conclude that the majority of car sales come from first owners with 77,49%, with the highest sales in 2017**

# %% [markdown]
# > **Another Visualization**

# %%
# Membuat Multi-Bar Chart
data16_20 = data[(data['year']>= 2016)]

data16_20.groupby(['year', 'seller_type'])['selling_price'].sum().unstack().plot(kind='bar')
plt.title('Total Selling Price in 2016-2020 - Breakdown by Seller Type (in Millions)', loc='center', pad=30, fontsize=15, color='blue')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Selling Price (in Millions)', fontsize=12)
plt.legend(bbox_to_anchor=(1,1), shadow=True, title='Seller Type')
plt.ylim(ymin=0)
labels, locations = plt.yticks()
plt.yticks(labels, (labels/1000000).astype(int))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Membuat Multi-Bar Chart
data16_20 = data[(data['year']>= 2016)]

data16_20.groupby(['year', 'seller_type'])['selling_price'].sum().unstack().plot(kind='bar', width=0.8, figsize = (15,10))
plt.title('Total Selling Price in 2016-2020 - Breakdown by Seller Type (in Millions)', loc='center', pad=30, fontsize=15, color='blue')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Selling Price (in Millions)', fontsize=12)
plt.legend(bbox_to_anchor=(1,1), shadow=True, title='Seller Type')
plt.ylim(ymin=0)
labels, locations = plt.yticks()
plt.yticks(labels, (labels/1000000).astype(int))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Membuat Stacked Chart

data16_20.groupby(['seller_type','year'])['selling_price'].sum().sort_values(ascending=False).unstack().plot(kind='bar', stacked=True)
plt.title('Total Selling Price Every Sellr Type - Breakdown by Year (in Millions)', loc='center', pad=30, fontsize=15, color='blue')
plt.xlabel('Seller Type', fontsize=12)
plt.ylabel('Total Selling Price (in Millions)', fontsize=12)
plt.legend(bbox_to_anchor=(1,1), shadow=True, ncol=1, title='City')
plt.ylim(ymin=0)
labels, locations = plt.yticks()
plt.yticks(labels, (labels/1000000).astype(int))
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Histogram

plt.clf()
# Histogram pertama
plt.figure()
plt.hist(data['year'])
plt.show()

# %%
# Histogram

plt.clf()
# Histogram pertama
plt.figure(figsize=(8,7))
plt.hist(data['owner'])
plt.show()

# %%
plt.figure()
plt.hist(data['year'], range=(2016,2020))
plt.title('Distribution of Number of Selling Car in 2016 - 2020', fontsize=15, color='blue')
plt.xlabel('Number of Year', fontsize=12)
plt.ylabel('Number of Selling Car', fontsize=12)
plt.show()

# %%
#KM Driven
plt.clf()
# Histogram pertama
plt.figure(figsize=(8,7))
plt.hist(data['km_driven'])
plt.show()

# %%
#Km Driven in 0 - 200.000 km
plt.figure(figsize=(10,5))
plt.hist(data['km_driven'], bins=100, range=(1,200000), color='brown')
plt.title('Distribution of Total KM Driven', fontsize=15, color='blue')
plt.xlabel('KM Driven', fontsize=12)
plt.ylabel('Number of Selling', fontsize=12)
plt.xlim(xmin=0, xmax=200000)
plt.show()

# %%
# Scatter Plot

plt.clf()

plt.figure()
plt.scatter(data['km_driven'], data['selling_price'])
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(data['km_driven'], data['selling_price'], marker='+', color='red')
plt.title('Correlation of KM driven and Selling Price', fontsize=15, color='blue')
plt.xlabel('KM Driven', fontsize=12)
plt.ylabel('Selling Price (in Millions)', fontsize=12)
plt.xlim(xmin=0, xmax=300000)
plt.ylim(ymin=0, ymax=10000000)
labels, locations = plt.yticks()

# %% [markdown]
# # **PANDAS PROFILING**

# %%
import pandas_profiling

pandas_profiling.ProfileReport(data)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-11-26 07:39:44.306196&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
